# %% [markdown]
# # Overview
#
# ## Main Purpose
#
# We would like to build a model to predict whether one is going to be defaulted on loan.
#
# In other words, we will build a model to automatically approve/disapprove one's loan request.
#
# ## About the data set
#
# - The data is taken from Kaggle.com
# - About 6000 entries with 13 features
#     - loan: amount of loan
#     - mortdue: amount of mortgage
#     - value: value of property (house)
#     - reason: reason for loan
#     - job: one's profession
#     - yoj: duration of employment
#     - **derog: number of bad/negative report**
#     - **delinq: number of delinquent credit line**
#     - clage: number of months of the oldest credit lines
#     - ninq: number of recent credit lines
#     - clno: total number of credit lines
#     - debtnc: debt to income ratio
#
# - Many missing values on important features
# - imbalanced
#
#
# ## Key Takeaway
#
# Some of features have a lot of missing values.
#
# The questions are whether we should drop them or fill them up.
#
# **DEROG** and **DELINQ** having many missing values, yet seem very important to decision making.
#
# If you were a banker, you would of course want to know your client's credit history.
#
# **We are going to build another (sub)model to predict and fill up the missing values of these features.**
#
# ## Steps
#
# 1. Information and description of the data
# 2. **Handle the missing values**
# 3. Undersampling -- accounting for imbalanced dependent varaible
# 4. Dropping variables
#     - correlation
#     - feautre selection -- which would work the best? why and why not others?
#     - feature extraction (?) -- would PCA be needed? why and why not?
# 5. Modeling
# 6. Evaluation
# 7. Conclusion
#
# ## Conclusion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('hmeq.csv')

# %%
df
# Out:
#       BAD   LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0       1   1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1       1   1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2       1   1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3       1   1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4       0   1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
# ...   ...    ...      ...       ...      ...     ...   ...    ...     ...
# 5955    0  88900  57264.0   90185.0  DebtCon   Other  16.0    0.0     0.0
# 5956    0  89000  54576.0   92937.0  DebtCon   Other  16.0    0.0     0.0
# 5957    0  89200  54045.0   92924.0  DebtCon   Other  15.0    0.0     0.0
# 5958    0  89800  50370.0   91861.0  DebtCon   Other  14.0    0.0     0.0
# 5959    0  89900  48811.0   88934.0  DebtCon   Other  15.0    0.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# ...

# %% [markdown]
# ### Information of the data set
#
# - 2 categorical features and 11 numerical features
# - Missing values
#
# **NOTE** 'BAD' feature is the dependent variable.
#
# It should be the categorical though its type is shown as integer.

# %%
df.info()
# sns.displot(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      5960 non-null   int64
#  1   LOAN     5960 non-null   int64
#  2   MORTDUE  5442 non-null   float64
#  3   VALUE    5848 non-null   float64
#  4   REASON   5708 non-null   object
#  5   JOB      5681 non-null   object
#  6   YOJ      5445 non-null   float64
#  7   DEROG    5252 non-null   float64
#  8   DELINQ   5380 non-null   float64
#  9   CLAGE    5652 non-null   float64
#  10  NINQ     5450 non-null   float64
#  11  CLNO     5738 non-null   float64
#  12  DEBTINC  4693 non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 605.4+ KB

# %%
# Change the int dtype to float to make it easy for later loop
df['BAD'] = df['BAD'].astype('float64')
df['LOAN'] = df['LOAN'].astype('float64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      5960 non-null   float64
#  1   LOAN     5960 non-null   float64
#  2   MORTDUE  5442 non-null   float64
#  3   VALUE    5848 non-null   float64
#  4   REASON   5708 non-null   object
#  5   JOB      5681 non-null   object
#  6   YOJ      5445 non-null   float64
#  7   DEROG    5252 non-null   float64
#  8   DELINQ   5380 non-null   float64
#  9   CLAGE    5652 non-null   float64
#  10  NINQ     5450 non-null   float64
#  11  CLNO     5738 non-null   float64
#  12  DEBTINC  4693 non-null   float64
# dtypes: float64(11), object(2)
# memory usage: 605.4+ KB

# %% [markdown]
# ### Descrition of the data set
#
# Almost all numerical features are skewed to right.
#
# In other words, their values at 75% percentile and Max have a huge gap.
#
# Better look in distribution plot

# %%
df.describe()
# Out:
#                BAD          LOAN        MORTDUE          VALUE          YOJ  \
# count  5960.000000   5960.000000    5442.000000    5848.000000  5445.000000
# mean      0.199497  18607.969799   73760.817200  101776.048741     8.922268
# std       0.399656  11207.480417   44457.609458   57385.775334     7.573982
# min       0.000000   1100.000000    2063.000000    8000.000000     0.000000
# 25%       0.000000  11100.000000   46276.000000   66075.500000     3.000000
# 50%       0.000000  16300.000000   65019.000000   89235.500000     7.000000
# 75%       0.000000  23300.000000   91488.000000  119824.250000    13.000000
# max       1.000000  89900.000000  399550.000000  855909.000000    41.000000
#
#              DEROG       DELINQ        CLAGE         NINQ         CLNO  \
# count  5252.000000  5380.000000  5652.000000  5450.000000  5738.000000
# mean      0.254570     0.449442   179.766275     1.186055    21.296096
# ...

# %%
df.columns[1:]
# Out:
# Index(['LOAN', 'MORTDUE', 'VALUE', 'REASON', 'JOB', 'YOJ', 'DEROG', 'DELINQ',
#        'CLAGE', 'NINQ', 'CLNO', 'DEBTINC'],
#       dtype='object')

# %%
# distribution of numerical variables
fig, axes = plt.subplots(2, 5, sharex = False, figsize=(16,8))

myfloats = [i for i in df.columns[1:] if df[i].dtype == 'float']

for num, col in enumerate(myfloats):
    sns.histplot(x = df[col],ax = axes[num//5,num%5])

# %%
# total number of missing values
df.isna().sum()
# Out:
# BAD           0
# LOAN          0
# MORTDUE     518
# VALUE       112
# REASON      252
# JOB         279
# YOJ         515
# DEROG       708
# DELINQ      580
# CLAGE       308
# NINQ        510
# CLNO        222
# DEBTINC    1267
# dtype: int64

# %%
# percentage of missing values
df.isna().sum() / len(df) * 100
# Out:
# BAD         0.000000
# LOAN        0.000000
# MORTDUE     8.691275
# VALUE       1.879195
# REASON      4.228188
# JOB         4.681208
# YOJ         8.640940
# DEROG      11.879195
# DELINQ      9.731544
# CLAGE       5.167785
# NINQ        8.557047
# CLNO        3.724832
# DEBTINC    21.258389
# dtype: float64

# %% [markdown]
# ## Missing Values
#
# ### Three methods
#     1. Dropping all the missing values.
#         - concern: lossing many entries.
#         - **However** Bagging from Random Forest may address this issue.
#     2. Median.
#         - concern: may not accurate.
#         - may not consider this option.
#     3. Regression.
#         - concern: regression assumptions are not met.
#         - may have too much work. Not sure if that would provide significant improvement in performance.
#
# I am going to drop the missing values.
#
# The idea of bagging in Random Forest may address the concern of low training set.
#
# I will also perform other algorithms to compare their performance.

# %%
df_dropped = df.dropna()
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3364 entries, 5 to 5959
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   BAD      3364 non-null   float64
#  1   LOAN     3364 non-null   float64
#  2   MORTDUE  3364 non-null   float64
#  3   VALUE    3364 non-null   float64
#  4   REASON   3364 non-null   object
#  5   JOB      3364 non-null   object
#  6   YOJ      3364 non-null   float64
#  7   DEROG    3364 non-null   float64
#  8   DELINQ   3364 non-null   float64
#  9   CLAGE    3364 non-null   float64
#  10  NINQ     3364 non-null   float64
#  11  CLNO     3364 non-null   float64
#  12  DEBTINC  3364 non-null   float64
# dtypes: float64(11), object(2)
# memory usage: 367.9+ KB

# %% [markdown]
# ## Undersampling

# %%
df_default = df_dropped[df_dropped['BAD'] == 1]
df_nondefault = df_dropped[df_dropped['BAD'] == 0]

returns_underS = df_nondefault.sample(n=len(df_default), random_state=100)
df_underS = pd.concat([df_default, returns_underS])
df_underS
# Out:
#       BAD     LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 5     1.0   1700.0  30548.0   40320.0  HomeImp   Other   9.0    0.0     0.0
# 7     1.0   1800.0  28502.0   43034.0  HomeImp   Other  11.0    0.0     0.0
# 25    1.0   2400.0  34863.0   47471.0  HomeImp     Mgr  12.0    0.0     0.0
# 36    1.0   2900.0   7750.0   67996.0  HomeImp   Other  16.0    3.0     0.0
# 37    1.0   2900.0  61962.0   70915.0  DebtCon     Mgr   2.0    0.0     0.0
# ...   ...      ...      ...       ...      ...     ...   ...    ...     ...
# 959   0.0   9200.0  52531.0   66491.0  DebtCon     Mgr  11.0    0.0     0.0
# 1543  0.0  11300.0  54984.0   63958.0  DebtCon     Mgr   4.0    0.0     0.0
# 1888  0.0  12500.0  53354.0   79893.0  HomeImp  Office  10.0    2.0     0.0
# 4797  0.0  25100.0  65633.0  100776.0  DebtCon   Other  15.0    0.0     1.0
# 5078  0.0  27100.0  44095.0   77587.0  DebtCon     Mgr  14.0    1.0     0.0
#
#            CLAGE  NINQ  CLNO    DEBTINC
# ...

# %% [markdown]
# ## Feature Selection
#
#
# ### Drop one of the correlated variables.
#
# ### PCA?
#
# No PCA. Why? --> Variables are not correlated to each other. PCs might not be very meaningful.

# %%
# corrrelation

plt.figure(figsize=(20,10))
sns.heatmap(df_underS.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df_underS = df_underS.drop(['VALUE'], axis=1)
plt.figure(figsize=(20,10))

sns.heatmap(df_underS.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Categorical Variables

# %%
myObjects = [i for i in df.columns[1:] if df[i].dtype == 'O']
print(myObjects)
# Out:
# ['REASON', 'JOB']

# %%
df_underS[myObjects].nunique()
# Out:
# REASON    2
# JOB       6
# dtype: int64

# %% [markdown]
# ### Chi-Sqaure Test
#
# #### 'REASON'
# It is binary variable.
#
# Getting dummy would not affect the total number of features.
#
# #### 'JOB'
# It has 6 sub-categories.
#
# It would increase the number of features.
#
# See if I can just drop it by performing Chi-Sqaure
#
# I would like to avoid the massive extension in number of columns due to the dummy variables.
#
# - Null: the column has no relationship with the dependent variable.
# - Alt: the column has relationship with the dependent variable.
#
# If it fails to reject the null, we say that the column has no relationship with the target variable (dependent varialbe)
#
# Ideally, many categorical columns turn out to be having high p values so that I will fail to reject the Null (Drop the column)

# %%
from scipy.stats import chi2_contingency

contTable = pd.crosstab(df_underS['JOB'],df['BAD'])
chi2_contingency(contTable)
# Out:
# (22.096051272921486,
#  0.0005020353155463273,
#  5,
#  array([[ 40.5,  40.5],
#         [ 50. ,  50. ],
#         [123. , 123. ],
#         [ 68.5,  68.5],
#         [  8. ,   8. ],
#         [ 10. ,  10. ]]))

# %%
print("P value is {}".format(chi2_contingency(contTable)[1]))
print("Since P value is very small, we reject the null.")
print("It means that the column has relationship with the dependent variable")
# Out:
# P value is 0.0005020353155463273
# Since P value is very small, we reject the null.
# It means that the column has relationship with the dependent variable

# %%
df_underS = pd.get_dummies(df_underS, columns = ['JOB','REASON'],drop_first = True)
df_underS
# Out:
#       BAD     LOAN  MORTDUE   YOJ  DEROG  DELINQ       CLAGE  NINQ  CLNO  \
# 5     1.0   1700.0  30548.0   9.0    0.0     0.0  101.466002   1.0   8.0
# 7     1.0   1800.0  28502.0  11.0    0.0     0.0   88.766030   0.0   8.0
# 25    1.0   2400.0  34863.0  12.0    0.0     0.0   70.491080   1.0  21.0
# 36    1.0   2900.0   7750.0  16.0    3.0     0.0  122.204663   2.0   8.0
# 37    1.0   2900.0  61962.0   2.0    0.0     0.0  282.801659   3.0  37.0
# ...   ...      ...      ...   ...    ...     ...         ...   ...   ...
# 959   0.0   9200.0  52531.0  11.0    0.0     0.0  122.228534   1.0  19.0
# 1543  0.0  11300.0  54984.0   4.0    0.0     0.0  190.920930   1.0  16.0
# 1888  0.0  12500.0  53354.0  10.0    2.0     0.0  249.435954   1.0  29.0
# 4797  0.0  25100.0  65633.0  15.0    0.0     1.0  141.938130   0.0  29.0
# 5078  0.0  27100.0  44095.0  14.0    1.0     0.0   92.140029   6.0  15.0
#
#         DEBTINC  JOB_Office  JOB_Other  JOB_ProfExe  JOB_Sales  JOB_Self  \
# ...

# %% [markdown]
# ## Splitting Data
#
# ### into X and y
#
# ### into Training and Test

# %%
X = df_underS.iloc[:,1:].values
y = df_underS.iloc[:,0].values

#Splitting the data into Training Set and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

#Normalizing the features
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.ensemble import RandomForestClassifier
classifierObj = RandomForestClassifier(criterion='entropy')
classifierObj.fit(X_train,y_train)

#Making predictions on the Test Set
y_pred = classifierObj.predict(X_test)

#Evaluating the predictions using a Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[88,  7],
#        [19, 66]])

# %%
print(classifierObj.score(X_test,y_test))
# Out:
# 0.8555555555555555

# %%
TP = cm[0][0]
FP = cm[0][1]
FN = cm[1][0]
TN = cm[1][1]

print("{} case(s) for 'we correctly predict that a client would default'".format(TP))
print("{} case(s) for 'we incorrectly predict that a client would default'".format(FP))
print("{} case(s) for 'we incorrectly predict that a client would not default'".format(FN))
print("{} case(s) for 'we correctly predict that a client would not default'".format(TN))
# Out:
# 88 case(s) for 'we correctly predict that a client would default'
# 7 case(s) for 'we incorrectly predict that a client would default'
# 19 case(s) for 'we incorrectly predict that a client would not default'
# 66 case(s) for 'we correctly predict that a client would not default'

# %%
from sklearn.metrics import precision_recall_fscore_support
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred)

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
print('support: {}'.format(support))
# Out:
# precision: [0.82242991 0.90410959]
# recall: [0.92631579 0.77647059]
# fscore: [0.87128713 0.83544304]
# support: [95 85]

# %%
precision = TP/(TP+FP)
recall = TP/(TP+FN)
print(precision,recall)
# Out:
# 0.9263157894736842 0.822429906542056
